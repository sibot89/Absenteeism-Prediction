# %%
from absenteeism_module import *

# %%
model = absenteeism_model('model','scaler')

# %%
model.load_and_clean_data('Absenteeism_new_data.csv')

# %%
model.predicted_outputs()
# Out:
#    Reason1  Reason2  Reason3  Reason4  Month  Transportation Expense  Age  \
# 0    False      0.0    False     True      7                     289   33
# 1    False      0.0    False    False      7                     118   50
# 2    False      0.0    False     True      7                     179   38
# 3     True      0.0    False    False      7                     279   39
# 4    False      0.0    False     True      7                     289   33
# 5    False      0.0    False     True      7                     179   38
# 6    False      0.0    False     True      7                     361   28
# 7    False      0.0    False     True      7                     260   36
# 8    False      0.0     True    False      7                     155   34
#
#    Body Mass Index  Education  Children  Pets  Probability  Prediction
# 0               30          0         2     1     0.536307           1
# 1               31          0         1     0     0.078836           0
# 2               31          0         0     0     0.230187           0
# 3               24          0         2     0     0.885513           1
# 4               30          0         2     1     0.536307           1
# 5               31          0         0     0     0.230187           0
# 6               27          0         1     4     0.323416           0
# 7               23          0         4     0     0.610429           1
# 8               25          0         2     0     0.862125           1

# %%
model.predicted_outputs().to_csv('Absenteeism_Predictions-for_New_Data.csv', index=False)
